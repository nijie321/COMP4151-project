# %%
import pandas

df = pandas.read_csv("BCHI-dataset_2019-03-04.csv")

# %%
len(df["Indicator Category"].unique())
# Out:
# 13

# %%
df.iloc[26382]
# Out:
# Indicator Category                                 Maternal and Child Health
# Indicator                      Infant Mortality Rate (Per 1,000 live births)
# Year                                                                    2010
# Sex                                                                     Both
# Race/Ethnicity                                                      Asian/PI
# Value                                                                      2
# Place                                                             Denver, CO
# BCHC Requested Methodology              Infant deaths per 1,000 live births.
# Source                                                         Vital Records
# Methods                                                                  NaN
# Notes                                                                    NaN
# 90% Confidence Level - Low                                               NaN
# 90% Confidence Level - High                                              NaN
# 95% Confidence Level - Low                                               NaN
# 95% Confidence Level - High                                              NaN
# Name: 26382, dtype: object

# %%
df.iloc[7833]
# Out:
# Indicator Category                                               Chronic Disease
# Indicator                      Percent of Adults Who Meet CDC-Recommended Phy...
# Year                                                                        2011
# Sex                                                                         Both
# Race/Ethnicity                                                          Hispanic
# Value                                                                       44.2
# Place                                               Oakland (Alameda County), CA
# BCHC Requested Methodology     BRFSS (or similar survey). Percent of populati...
# Source                                                          CHIS- 2005, 2009
# Methods                        Adults 18+ years, Moderate physical activity a...
# Notes                                                                        NaN
# 90% Confidence Level - Low                                                   NaN
# 90% Confidence Level - High                                                  NaN
# 95% Confidence Level - Low                                                   NaN
# 95% Confidence Level - High                                                  NaN
# Name: 7833, dtype: object

# %%
df.iloc[10682]
# Out:
# Indicator Category                                                  Demographics
# Indicator                                Percent of Population with a Disability
# Year                                                                        2016
# Sex                                                                         Both
# Race/Ethnicity                                                          Hispanic
# Value                                                                        8.9
# Place                                                            Los Angeles, CA
# BCHC Requested Methodology     Percentage of the population with a disability...
# Source                         US Census Bureau, American Community Survey 1-...
# Methods                                                                      NaN
# Notes                                                                        NaN
# 90% Confidence Level - Low                                                   NaN
# 90% Confidence Level - High                                                  NaN
# 95% Confidence Level - Low                                                   NaN
# 95% Confidence Level - High                                                  NaN
# Name: 10682, dtype: object

# %%
df.iloc[26701]
# Out:
# Indicator Category                                     Maternal and Child Health
# Indicator                          Infant Mortality Rate (Per 1,000 live births)
# Year                                                                        2012
# Sex                                                                         Both
# Race/Ethnicity                                                             White
# Value                                                                          5
# Place                                                            San Antonio, TX
# BCHC Requested Methodology                  Infant deaths per 1,000 live births.
# Source                         Bexar County resident, SA Metro Health Birth a...
# Methods                                                                      NaN
# Notes                                                     Bexar County Residents
# 90% Confidence Level - Low                                                   NaN
# 90% Confidence Level - High                                                  NaN
# 95% Confidence Level - Low                                                   NaN
# 95% Confidence Level - High                                                  NaN
# Name: 26701, dtype: object

# %%
df.loc[df["Indicator"] == "Median Household Income (Dollars)"]
# Out:
#                 Indicator Category                          Indicator  Year  \
# 31919  Social and Economic Factors  Median Household Income (Dollars)  2012
# 31920  Social and Economic Factors  Median Household Income (Dollars)  2012
# 31921  Social and Economic Factors  Median Household Income (Dollars)  2012
# 31922  Social and Economic Factors  Median Household Income (Dollars)  2012
# 31923  Social and Economic Factors  Median Household Income (Dollars)  2012
# 31924  Social and Economic Factors  Median Household Income (Dollars)  2012
# 31925  Social and Economic Factors  Median Household Income (Dollars)  2012
# 31926  Social and Economic Factors  Median Household Income (Dollars)  2012
# 31927  Social and Economic Factors  Median Household Income (Dollars)  2012
# 31928  Social and Economic Factors  Median Household Income (Dollars)  2012
# 31929  Social and Economic Factors  Median Household Income (Dollars)  2012
# 31930  Social and Economic Factors  Median Household Income (Dollars)  2012
# 31931  Social and Economic Factors  Median Household Income (Dollars)  2012
# 31932  Social and Economic Factors  Median Household Income (Dollars)  2012
# 31933  Social and Economic Factors  Median Household Income (Dollars)  2012
# 31934  Social and Economic Factors  Median Household Income (Dollars)  2012
# 31935  Social and Economic Factors  Median Household Income (Dollars)  2012
# 31936  Social and Economic Factors  Median Household Income (Dollars)  2012
# 31937  Social and Economic Factors  Median Household Income (Dollars)  2012
# 31938  Social and Economic Factors  Median Household Income (Dollars)  2012
# 31939  Social and Economic Factors  Median Household Income (Dollars)  2013
# 31940  Social and Economic Factors  Median Household Income (Dollars)  2013
# 31941  Social and Economic Factors  Median Household Income (Dollars)  2013
# 31942  Social and Economic Factors  Median Household Income (Dollars)  2013
# 31943  Social and Economic Factors  Median Household Income (Dollars)  2013
# 31944  Social and Economic Factors  Median Household Income (Dollars)  2013
# 31945  Social and Economic Factors  Median Household Income (Dollars)  2013
# 31946  Social and Economic Factors  Median Household Income (Dollars)  2013
# 31947  Social and Economic Factors  Median Household Income (Dollars)  2013
# 31948  Social and Economic Factors  Median Household Income (Dollars)  2013
# ...                            ...                                ...   ...
# 32027  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32028  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32029  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32030  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32031  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32032  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32033  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32034  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32035  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32036  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32037  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32038  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32039  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32040  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32041  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32042  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32043  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32044  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32045  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32046  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32047  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32048  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32049  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32050  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32051  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32052  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32053  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32054  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32055  Social and Economic Factors  Median Household Income (Dollars)  2016
# 32056  Social and Economic Factors  Median Household Income (Dollars)  2016
#
#         Sex Race/Ethnicity     Value                             Place  \
# 31919  Both            All   23600.0                       Detroit, MI
# 31920  Both            All   24257.0                     Cleveland, OH
# 31921  Both            All   35386.0                  Philadelphia, PA
# 31922  Both            All   39241.0                     Baltimore, MD
# 31923  Both            All   41354.0                        Dallas, TX
# 31924  Both            All   41877.0                   Kansas City, MO
# 31925  Both            All   44153.0                       Phoenix, AZ
# 31926  Both            All   45214.0                       Chicago, Il
# 31927  Both            All   45524.0                   San Antonio, TX
# 31928  Both            All   46803.0                   Los Angeles, CA
# 31929  Both            All   47604.0                   Minneapolis, MN
# 31930  Both            All   48196.0      Oakland (Alameda County), CA
# 31931  Both            All   50488.0                        Denver, CO
# 31932  Both            All   50895.0                 New York City, NY
# 31933  Both            All   51642.0                        Boston, MA
# 31934  Both            All   52430.0                       Houston, TX
# 31935  Both            All   64473.0                       Seattle, WA
# 31936  Both            All   66583.0                    Washington, DC
# 31937  Both            All   73012.0                 San Francisco, CA
# 31938  Both            All   80090.0                      San Jose, CA
# 31939  Both            All   24820.0                       Detroit, MI
# 31940  Both            All   26096.0                     Cleveland, OH
# 31941  Both            All   36836.0                  Philadelphia, PA
# 31942  Both            All   41978.0                        Dallas, TX
# 31943  Both            All   42250.0            U.S. Total, U.S. Total
# 31944  Both            All   42266.0                     Baltimore, MD
# 31945  Both            All   43100.0     Miami (Miami-Dade County), FL
# 31946  Both            All   45353.0                       Houston, TX
# 31947  Both            All   45399.0                   San Antonio, TX
# 31948  Both            All   45551.0                   Kansas City, MO
# ...     ...            ...       ...                               ...
# 32027  Both            All   28099.0                       Detroit, MI
# 32028  Both            All   41449.0                  Philadelphia, PA
# 32029  Both            All   44874.0  Indianapolis (Marion County), IN
# 32030  Both            All   45935.0     Miami (Miami-Dade County), FL
# 32031  Both            All   47350.0                     Baltimore, MD
# 32032  Both            All   47793.0                       Houston, TX
# 32033  Both            All   49268.0                   San Antonio, TX
# 32034  Both            All   51235.0                   Kansas City, MO
# 32035  Both            All   52062.0                       Phoenix, AZ
# 32036  Both            All   53006.0                       Chicago, Il
# 32037  Both            All   54384.0      Las Vegas (Clark County), NV
# 32038  Both            All   54399.0                        Dallas, TX
# 32039  Both            All   54432.0                   Los Angeles, CA
# 32040  Both            All   56055.0                      Columbus, OH
# 32041  Both            All   56255.0                   Minneapolis, MN
# 32042  Both            All   57617.0            U.S. Total, U.S. Total
# 32043  Both            All   58856.0                 New York City, NY
# 32044  Both            All   60075.0                    Long Beach, CA
# 32045  Both            All   61105.0                        Denver, CO
# 32046  Both            All   61534.0   Fort Worth (Tarrant County), TX
# 32047  Both            All   62629.0   Portland (Multnomah County), OR
# 32048  Both            All   62978.0                     Charlotte, NC
# 32049  Both            All   63621.0                        Boston, MA
# 32050  Both            All   68060.0      Oakland (Alameda County), CA
# 32051  Both            All   70158.0                        Austin, TX
# 32052  Both            All   70824.0              San Diego County, CA
# 32053  Both            All   75506.0                    Washington, DC
# 32054  Both            All   83476.0                       Seattle, WA
# 32055  Both            All  101940.0                      San Jose, CA
# 32056  Both            All  103801.0                 San Francisco, CA
#
#                               BCHC Requested Methodology  \
# 31919  Median household income (in 2012 inflation-adj...
# 31920  Median household income (in 2012 inflation-adj...
# 31921  Median household income (in 2012 inflation-adj...
# 31922  Median household income (in 2012 inflation-adj...
# 31923  Median household income (in 2012 inflation-adj...
# 31924  Median household income (in 2012 inflation-adj...
# 31925  Median household income (in 2012 inflation-adj...
# 31926  Median household income (in 2012 inflation-adj...
# 31927  Median household income (in 2012 inflation-adj...
# 31928  Median household income (in 2012 inflation-adj...
# 31929  Median household income (in 2012 inflation-adj...
# 31930  Median household income (in 2012 inflation-adj...
# 31931  Median household income (in 2012 inflation-adj...
# 31932  Median household income (in 2012 inflation-adj...
# 31933  Median household income (in 2012 inflation-adj...
# 31934  Median household income (in 2012 inflation-adj...
# 31935  Median household income (in 2012 inflation-adj...
# 31936  Median household income (in 2012 inflation-adj...
# 31937  Median household income (in 2012 inflation-adj...
# 31938  Median household income (in 2012 inflation-adj...
# 31939  Median household income (in 2013 inflation-adj...
# 31940  Median household income (in 2013 inflation-adj...
# 31941  Median household income (in 2013 inflation-adj...
# 31942  Median household income (in 2013 inflation-adj...
# 31943  Median household income (in 2013 inflation-adj...
# 31944  Median household income (in 2013 inflation-adj...
# 31945  Median household income (in 2013 inflation-adj...
# 31946  Median household income (in 2013 inflation-adj...
# 31947  Median household income (in 2013 inflation-adj...
# 31948  Median household income (in 2013 inflation-adj...
# ...                                                  ...
# 32027  Median household income (in 2016 inflation-adj...
# 32028  Median household income (in 2016 inflation-adj...
# 32029  Median household income (in 2016 inflation-adj...
# 32030  Median household income (in 2016 inflation-adj...
# 32031  Median household income (in 2016 inflation-adj...
# 32032  Median household income (in 2016 inflation-adj...
# 32033  Median household income (in 2016 inflation-adj...
# 32034  Median household income (in 2016 inflation-adj...
# 32035  Median household income (in 2016 inflation-adj...
# 32036  Median household income (in 2016 inflation-adj...
# 32037  Median household income (in 2016 inflation-adj...
# 32038  Median household income (in 2016 inflation-adj...
# 32039  Median household income (in 2016 inflation-adj...
# 32040  Median household income (in 2016 inflation-adj...
# 32041  Median household income (in 2016 inflation-adj...
# 32042  Median household income (in 2016 inflation-adj...
# 32043  Median household income (in 2016 inflation-adj...
# 32044  Median household income (in 2016 inflation-adj...
# 32045  Median household income (in 2016 inflation-adj...
# 32046  Median household income (in 2016 inflation-adj...
# 32047  Median household income (in 2016 inflation-adj...
# 32048  Median household income (in 2016 inflation-adj...
# 32049  Median household income (in 2016 inflation-adj...
# 32050  Median household income (in 2016 inflation-adj...
# 32051  Median household income (in 2016 inflation-adj...
# 32052  Median household income (in 2016 inflation-adj...
# 32053  Median household income (in 2016 inflation-adj...
# 32054  Median household income (in 2016 inflation-adj...
# 32055  Median household income (in 2016 inflation-adj...
# 32056  Median household income (in 2016 inflation-adj...
#
#                                                   Source Methods  \
# 31919  US Census Bureau, American Community Survey 1-...     NaN
# 31920  US Census Bureau, American Community Survey 1-...     NaN
# 31921  US Census Bureau, American Community Survey 1-...     NaN
# 31922  US Census Bureau, American Community Survey 1-...     NaN
# 31923  US Census Bureau, American Community Survey 1-...     NaN
# 31924  US Census Bureau, American Community Survey 1-...     NaN
# 31925  US Census Bureau, American Community Survey 1-...     NaN
# 31926  US Census Bureau, American Community Survey 1-...     NaN
# 31927  US Census Bureau, American Community Survey 1-...     NaN
# 31928  US Census Bureau, American Community Survey 1-...     NaN
# 31929  US Census Bureau, American Community Survey 1-...     NaN
# 31930  US Census Bureau, American Community Survey 1-...     NaN
# 31931  US Census Bureau, American Community Survey 1-...     NaN
# 31932  US Census Bureau, American Community Survey 1-...     NaN
# 31933  US Census Bureau, American Community Survey 1-...     NaN
# 31934  US Census Bureau, American Community Survey 1-...     NaN
# 31935  US Census Bureau, American Community Survey 1-...     NaN
# 31936  US Census Bureau, American Community Survey 1-...     NaN
# 31937  US Census Bureau, American Community Survey 1-...     NaN
# 31938  US Census Bureau, American Community Survey 1-...     NaN
# 31939  US Census Bureau, American Community Survey 1-...     NaN
# 31940  US Census Bureau, American Community Survey 1-...     NaN
# 31941  US Census Bureau, American Community Survey 1-...     NaN
# 31942  US Census Bureau, American Community Survey 1-...     NaN
# 31943  US Census Bureau, American Community Survey 1-...     NaN
# 31944  US Census Bureau, American Community Survey 1-...     NaN
# 31945  US Census Bureau, American Community Survey 1-...     NaN
# 31946  US Census Bureau, American Community Survey 1-...     NaN
# 31947  US Census Bureau, American Community Survey 1-...     NaN
# 31948  US Census Bureau, American Community Survey 1-...     NaN
# ...                                                  ...     ...
# 32027  US Census Bureau, American Community Survey 1-...     NaN
# 32028  US Census Bureau, American Community Survey 1-...     NaN
# 32029  US Census Bureau, American Community Survey 1-...     NaN
# 32030  US Census Bureau, American Community Survey 1-...     NaN
# 32031  US Census Bureau, American Community Survey 1-...     NaN
# 32032  US Census Bureau, American Community Survey 1-...     NaN
# 32033  US Census Bureau, American Community Survey 1-...     NaN
# 32034  US Census Bureau, American Community Survey 1-...     NaN
# 32035  US Census Bureau, American Community Survey 1-...     NaN
# 32036  US Census Bureau, American Community Survey 1-...     NaN
# 32037  US Census Bureau, American Community Survey 1-...     NaN
# 32038  US Census Bureau, American Community Survey 1-...     NaN
# 32039  US Census Bureau, American Community Survey 1-...     NaN
# 32040  US Census Bureau, American Community Survey 1-...     NaN
# 32041  US Census Bureau, American Community Survey 1-...     NaN
# 32042  US Census Bureau, American Community Survey 1-...     NaN
# 32043  US Census Bureau, American Community Survey 1-...     NaN
# 32044  US Census Bureau, American Community Survey 1-...     NaN
# 32045  US Census Bureau, American Community Survey 1-...     NaN
# 32046  US Census Bureau, American Community Survey 1-...     NaN
# 32047  US Census Bureau, American Community Survey 1-...     NaN
# 32048  US Census Bureau, American Community Survey 1-...     NaN
# 32049  US Census Bureau, American Community Survey 1-...     NaN
# 32050  US Census Bureau, American Community Survey 1-...     NaN
# 32051  US Census Bureau, American Community Survey 1-...     NaN
# 32052  US Census Bureau, American Community Survey 1-...     NaN
# 32053  US Census Bureau, American Community Survey 1-...     NaN
# 32054  US Census Bureau, American Community Survey 1-...     NaN
# 32055  US Census Bureau, American Community Survey 1-...     NaN
# 32056  US Census Bureau, American Community Survey 1-...     NaN
#
#                                                    Notes  \
# 31919  FIPS code 2622000 was used to isolate data for...
# 31920  FIPS code 3916000 was used to isolate data for...
# 31921  FIPS code 4260000 was used to isolate data for...
# 31922  FIPS code 2404000 was used to isolate data for...
# 31923  FIPS code 48113 was used to isolate data for D...
# 31924  FIPS code 2938000 was used to isolate data for...
# 31925  FIPS code 0455000 was used to isolate data for...
# 31926  Place=Chicago was used to isolate American Com...
# 31927  FIPS code 4865000 was used to isolate data for...
# 31928  FIPS code 0644000 was used to isolate data for...
# 31929  FIPS code 2743000 was used to isolate data for...
# 31930  FIPS code 0653000 was used to isolate data for...
# 31931  FIPS code 0820000 was used to isolate data for...
# 31932  FIPS code 3651000 was used to isolate data for...
# 31933  FIPS code 2507000 was used to isolate data for...
# 31934  FIPS code 4835000 was used to isolate data for...
# 31935  FIPS code 5363000 was used to isolate data for...
# 31936  FIPS code 1150000 was used to isolate data for...
# 31937  FIPS code 0667000 was used to isolate data for...
# 31938  FIPS code 0668000 was used to isolate data for...
# 31939  FIPS code 2622000 was used to isolate data for...
# 31940  FIPS code 3916000 was used to isolate data for...
# 31941  FIPS code 4260000 was used to isolate data for...
# 31942  FIPS code 48113 was used to isolate data for D...
# 31943                                                NaN
# 31944  FIPS code 2404000 was used to isolate data for...
# 31945  FIPS code 12086 was used to isolate data for M...
# 31946  FIPS code 4835000 was used to isolate data for...
# 31947  FIPS code 4865000 was used to isolate data for...
# 31948  FIPS code 2938000 was used to isolate data for...
# ...                                                  ...
# 32027  FIPS code 2622000 was used to isolate data for...
# 32028  FIPS code 4260000 was used to isolate data for...
# 32029                                                NaN
# 32030  FIPS code 12086 was used to isolate data for M...
# 32031  FIPS code 2404000 was used to isolate data for...
# 32032  FIPS code 4835000 was used to isolate data for...
# 32033  FIPS code 4865000 was used to isolate data for...
# 32034  FIPS code 2938000 was used to isolate data for...
# 32035  FIPS code 0455000 was used to isolate data for...
# 32036  Place=Chicago was used to isolate American Com...
# 32037  FIPS code 32003 was used to isolate data for L...
# 32038  FIPS code 48113 was used to isolate data for D...
# 32039  FIPS code 0644000 was used to isolate data for...
# 32040                                                NaN
# 32041  FIPS code 2743000 was used to isolate data for...
# 32042                                                NaN
# 32043  FIPS code 3651000 was used to isolate data for...
# 32044  FIPS code 0643000 was used to isolate data for...
# 32045  FIPS code 0820000 was used to isolate data for...
# 32046  FIPS code 48439 was used to isolate data for F...
# 32047  FIPS code 41051 was used to isolate data for P...
# 32048                                                NaN
# 32049  FIPS code 2507000 was used to isolate data for...
# 32050  FIPS code 0653000 was used to isolate data for...
# 32051                                                NaN
# 32052  FIPS code 06073 was used to isolate data for S...
# 32053  FIPS code 1150000 was used to isolate data for...
# 32054  FIPS code 5363000 was used to isolate data for...
# 32055  FIPS code 0668000 was used to isolate data for...
# 32056  FIPS code 0667000 was used to isolate data for...
#
#        90% Confidence Level - Low  90% Confidence Level - High  \
# 31919                         NaN                          NaN
# 31920                         NaN                          NaN
# 31921                         NaN                          NaN
# 31922                         NaN                          NaN
# 31923                         NaN                          NaN
# 31924                         NaN                          NaN
# 31925                         NaN                          NaN
# 31926                         NaN                          NaN
# 31927                         NaN                          NaN
# 31928                         NaN                          NaN
# 31929                         NaN                          NaN
# 31930                         NaN                          NaN
# 31931                         NaN                          NaN
# 31932                         NaN                          NaN
# 31933                         NaN                          NaN
# 31934                         NaN                          NaN
# 31935                         NaN                          NaN
# 31936                         NaN                          NaN
# 31937                         NaN                          NaN
# 31938                         NaN                          NaN
# 31939                         NaN                          NaN
# 31940                         NaN                          NaN
# 31941                         NaN                          NaN
# 31942                         NaN                          NaN
# 31943                         NaN                          NaN
# 31944                         NaN                          NaN
# 31945                         NaN                          NaN
# 31946                         NaN                          NaN
# 31947                         NaN                          NaN
# 31948                         NaN                          NaN
# ...                           ...                          ...
# 32027                         NaN                          NaN
# 32028                         NaN                          NaN
# 32029                         NaN                          NaN
# 32030                         NaN                          NaN
# 32031                         NaN                          NaN
# 32032                         NaN                          NaN
# 32033                         NaN                          NaN
# 32034                         NaN                          NaN
# 32035                         NaN                          NaN
# 32036                         NaN                          NaN
# 32037                         NaN                          NaN
# 32038                         NaN                          NaN
# 32039                         NaN                          NaN
# 32040                         NaN                          NaN
# 32041                         NaN                          NaN
# 32042                         NaN                          NaN
# 32043                         NaN                          NaN
# 32044                         NaN                          NaN
# 32045                         NaN                          NaN
# 32046                         NaN                          NaN
# 32047                         NaN                          NaN
# 32048                         NaN                          NaN
# 32049                         NaN                          NaN
# 32050                         NaN                          NaN
# 32051                         NaN                          NaN
# 32052                         NaN                          NaN
# 32053                         NaN                          NaN
# 32054                         NaN                          NaN
# 32055                         NaN                          NaN
# 32056                         NaN                          NaN
#
#        95% Confidence Level - Low  95% Confidence Level - High
# 31919                         NaN                          NaN
# 31920                         NaN                          NaN
# 31921                         NaN                          NaN
# 31922                         NaN                          NaN
# 31923                         NaN                          NaN
# 31924                         NaN                          NaN
# 31925                         NaN                          NaN
# 31926                         NaN                          NaN
# 31927                         NaN                          NaN
# 31928                         NaN                          NaN
# 31929                         NaN                          NaN
# 31930                         NaN                          NaN
# 31931                         NaN                          NaN
# 31932                         NaN                          NaN
# 31933                         NaN                          NaN
# 31934                         NaN                          NaN
# 31935                         NaN                          NaN
# 31936                         NaN                          NaN
# 31937                         NaN                          NaN
# 31938                         NaN                          NaN
# 31939                         NaN                          NaN
# 31940                         NaN                          NaN
# 31941                         NaN                          NaN
# 31942                         NaN                          NaN
# 31943                         NaN                          NaN
# 31944                         NaN                          NaN
# 31945                         NaN                          NaN
# 31946                         NaN                          NaN
# 31947                         NaN                          NaN
# 31948                         NaN                          NaN
# ...                           ...                          ...
# 32027                         NaN                          NaN
# 32028                         NaN                          NaN
# 32029                         NaN                          NaN
# 32030                         NaN                          NaN
# 32031                         NaN                          NaN
# 32032                         NaN                          NaN
# 32033                         NaN                          NaN
# 32034                         NaN                          NaN
# 32035                         NaN                          NaN
# 32036                         NaN                          NaN
# 32037                         NaN                          NaN
# 32038                         NaN                          NaN
# 32039                         NaN                          NaN
# 32040                         NaN                          NaN
# 32041                         NaN                          NaN
# 32042                         NaN                          NaN
# 32043                         NaN                          NaN
# 32044                         NaN                          NaN
# 32045                         NaN                          NaN
# 32046                         NaN                          NaN
# 32047                         NaN                          NaN
# 32048                         NaN                          NaN
# 32049                         NaN                          NaN
# 32050                         NaN                          NaN
# 32051                         NaN                          NaN
# 32052                         NaN                          NaN
# 32053                         NaN                          NaN
# 32054                         NaN                          NaN
# 32055                         NaN                          NaN
# 32056                         NaN                          NaN
#
# [138 rows x 15 columns]

# %%
len(df["Place"].unique())
# Out:
# 31

# %%
df.loc[df["Indicator"] == "Percent of Adults Who Are Obese"]
# Out:
#      Indicator Category                        Indicator  Year     Sex  \
# 6502    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6503    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6504    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6505    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6506    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6507    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6508    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6509    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6510    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6511    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6512    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6513    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6514    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6515    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6516    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6517    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6518    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6519    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6520    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6521    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6522    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6523    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6524    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6525    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6526    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6527    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6528    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6529    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6530    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# 6531    Chronic Disease  Percent of Adults Who Are Obese  2010    Both
# ...                 ...                              ...   ...     ...
# 7146    Chronic Disease  Percent of Adults Who Are Obese  2015    Male
# 7147    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7148    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7149    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7150    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7151    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7152    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7153    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7154    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7155    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7156    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7157    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7158    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7159    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7160    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7161    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7162    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7163    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7164    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7165    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7166    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7167    Chronic Disease  Percent of Adults Who Are Obese  2016    Both
# 7168    Chronic Disease  Percent of Adults Who Are Obese  2016  Female
# 7169    Chronic Disease  Percent of Adults Who Are Obese  2016  Female
# 7170    Chronic Disease  Percent of Adults Who Are Obese  2016  Female
# 7171    Chronic Disease  Percent of Adults Who Are Obese  2016  Female
# 7172    Chronic Disease  Percent of Adults Who Are Obese  2016    Male
# 7173    Chronic Disease  Percent of Adults Who Are Obese  2016    Male
# 7174    Chronic Disease  Percent of Adults Who Are Obese  2016    Male
# 7175    Chronic Disease  Percent of Adults Who Are Obese  2016    Male
#
#      Race/Ethnicity  Value                            Place  \
# 6502            All   18.0                      Seattle, WA
# 6503            All   20.3                       Boston, MA
# 6504            All   26.1             San Diego County, CA
# 6505            All   26.7                    Charlotte, NC
# 6506            All   29.2                    Baltimore, MD
# 6507            All   29.3    Miami (Miami-Dade County), FL
# 6508            All   30.6                      Houston, TX
# 6509            All   31.4                      Chicago, Il
# 6510            All   32.2                 Philadelphia, PA
# 6511            All   32.4                  San Antonio, TX
# 6512            All   33.6  Fort Worth (Tarrant County), TX
# 6513       Asian/PI    NaN                     Columbus, OH
# 6514       Asian/PI    NaN                      Seattle, WA
# 6515          Black   28.5                  San Antonio, TX
# 6516          Black   32.3                       Boston, MA
# 6517          Black   32.8                    Baltimore, MD
# 6518          Black   35.5                      Chicago, Il
# 6519          Black   37.0                      Seattle, WA
# 6520          Black   38.2    Miami (Miami-Dade County), FL
# 6521          Black   38.4                 Philadelphia, PA
# 6522          Black   39.4                    Charlotte, NC
# 6523          Black   45.0                      Houston, TX
# 6524       Hispanic   28.5                       Boston, MA
# 6525       Hispanic   29.2                      Chicago, Il
# 6526       Hispanic   30.6    Miami (Miami-Dade County), FL
# 6527       Hispanic   35.9                 Philadelphia, PA
# 6528       Hispanic   38.7                      Houston, TX
# 6529       Hispanic   39.6                  San Antonio, TX
# 6530       Hispanic   45.0                      Seattle, WA
# 6531       Hispanic    NaN                     Columbus, OH
# ...             ...    ...                              ...
# 7146            All    NaN                San Francisco, CA
# 7147            All   18.5                       Denver, CO
# 7148            All   26.9     Oakland (Alameda County), CA
# 7149            All   28.0                 Philadelphia, PA
# 7150            All   31.6                  Kansas City, MO
# 7151            All   33.1                     Columbus, OH
# 7152       Asian/PI    NaN                     Columbus, OH
# 7153       Asian/PI    NaN                       Denver, CO
# 7154       Asian/PI    NaN     Oakland (Alameda County), CA
# 7155          Black   32.3                     Columbus, OH
# 7156          Black   34.2                       Denver, CO
# 7157          Black   36.0                 Philadelphia, PA
# 7158          Black    NaN     Oakland (Alameda County), CA
# 7159       Hispanic   21.8                       Denver, CO
# 7160       Hispanic    NaN                     Columbus, OH
# 7161       Hispanic    NaN     Oakland (Alameda County), CA
# 7162          Other   14.2                       Denver, CO
# 7163          Other    NaN                     Columbus, OH
# 7164          White   15.1                       Denver, CO
# 7165          White   23.0                 Philadelphia, PA
# 7166          White   32.2                     Columbus, OH
# 7167          White    NaN     Oakland (Alameda County), CA
# 7168            All   19.3                       Denver, CO
# 7169            All   31.0                     Columbus, OH
# 7170            All   36.0                 Philadelphia, PA
# 7171            All    NaN     Oakland (Alameda County), CA
# 7172            All   17.8                       Denver, CO
# 7173            All   20.0                 Philadelphia, PA
# 7174            All   35.2                     Columbus, OH
# 7175            All    NaN     Oakland (Alameda County), CA
#
#                              BCHC Requested Methodology  \
# 6502  BRFSS (or similar survey). Percent of populati...
# 6503  BRFSS (or similar survey). Percent of populati...
# 6504  BRFSS (or similar survey). Percent of populati...
# 6505  BRFSS (or similar survey). Percent of populati...
# 6506  BRFSS (or similar survey). Percent of populati...
# 6507  BRFSS (or similar survey). Percent of populati...
# 6508  BRFSS (or similar survey). Percent of populati...
# 6509  BRFSS (or similar survey). Percent of populati...
# 6510  BRFSS (or similar survey). Percent of populati...
# 6511  BRFSS (or similar survey). Percent of populati...
# 6512  BRFSS (or similar survey). Percent of populati...
# 6513  BRFSS (or similar survey). Percent of populati...
# 6514  BRFSS (or similar survey). Percent of populati...
# 6515  BRFSS (or similar survey). Percent of populati...
# 6516  BRFSS (or similar survey). Percent of populati...
# 6517  BRFSS (or similar survey). Percent of populati...
# 6518  BRFSS (or similar survey). Percent of populati...
# 6519  BRFSS (or similar survey). Percent of populati...
# 6520  BRFSS (or similar survey). Percent of populati...
# 6521  BRFSS (or similar survey). Percent of populati...
# 6522  BRFSS (or similar survey). Percent of populati...
# 6523  BRFSS (or similar survey). Percent of populati...
# 6524  BRFSS (or similar survey). Percent of populati...
# 6525  BRFSS (or similar survey). Percent of populati...
# 6526  BRFSS (or similar survey). Percent of populati...
# 6527  BRFSS (or similar survey). Percent of populati...
# 6528  BRFSS (or similar survey). Percent of populati...
# 6529  BRFSS (or similar survey). Percent of populati...
# 6530  BRFSS (or similar survey). Percent of populati...
# 6531  BRFSS (or similar survey). Percent of populati...
# ...                                                 ...
# 7146  BRFSS (or similar survey). Percent of populati...
# 7147  BRFSS (or similar survey). Percent of populati...
# 7148  BRFSS (or similar survey). Percent of populati...
# 7149  BRFSS (or similar survey). Percent of populati...
# 7150  BRFSS (or similar survey). Percent of populati...
# 7151  BRFSS (or similar survey). Percent of populati...
# 7152  BRFSS (or similar survey). Percent of populati...
# 7153  BRFSS (or similar survey). Percent of populati...
# 7154  BRFSS (or similar survey). Percent of populati...
# 7155  BRFSS (or similar survey). Percent of populati...
# 7156  BRFSS (or similar survey). Percent of populati...
# 7157  BRFSS (or similar survey). Percent of populati...
# 7158  BRFSS (or similar survey). Percent of populati...
# 7159  BRFSS (or similar survey). Percent of populati...
# 7160  BRFSS (or similar survey). Percent of populati...
# 7161  BRFSS (or similar survey). Percent of populati...
# 7162  BRFSS (or similar survey). Percent of populati...
# 7163  BRFSS (or similar survey). Percent of populati...
# 7164  BRFSS (or similar survey). Percent of populati...
# 7165  BRFSS (or similar survey). Percent of populati...
# 7166  BRFSS (or similar survey). Percent of populati...
# 7167  BRFSS (or similar survey). Percent of populati...
# 7168  BRFSS (or similar survey). Percent of populati...
# 7169  BRFSS (or similar survey). Percent of populati...
# 7170  BRFSS (or similar survey). Percent of populati...
# 7171  BRFSS (or similar survey). Percent of populati...
# 7172  BRFSS (or similar survey). Percent of populati...
# 7173  BRFSS (or similar survey). Percent of populati...
# 7174  BRFSS (or similar survey). Percent of populati...
# 7175  BRFSS (or similar survey). Percent of populati...
#
#                                                  Source  \
# 6502                                              BRFSS
# 6503  Boston Behavioral Risk Factor Survey, Boston P...
# 6504  Centers for Disease Control and Prevention (CD...
# 6505                 2010 NC BRFSS (Mecklenburg Sample)
# 6506                                          CDC BRFSS
# 6507  Florida Behavioral Risk Factor Surveillance Sy...
# 6508  Source: Texas Behavioral Risk Factor Surveilla...
# 6509                                                NaN
# 6510  Public Health Management Corporation (PHMC) Ho...
# 6511  Data is pulled from the Texas State Health & H...
# 6512  Behavior Risk Factors: Selected Metropolitan A...
# 6513                                                NaN
# 6514                                              BRFSS
# 6515  Data is pulled from the Texas State Health & H...
# 6516  Boston Behavioral Risk Factor Survey, Boston P...
# 6517                                          CDC BRFSS
# 6518                                                NaN
# 6519                                              BRFSS
# 6520  Florida Behavioral Risk Factor Surveillance Sy...
# 6521  Public Health Management Corporation (PHMC) Ho...
# 6522                 2010 NC BRFSS (Mecklenburg Sample)
# 6523  Source: Texas Behavioral Risk Factor Surveilla...
# 6524  Boston Behavioral Risk Factor Survey, Boston P...
# 6525                                                NaN
# 6526  Florida Behavioral Risk Factor Surveillance Sy...
# 6527  Public Health Management Corporation (PHMC) Ho...
# 6528  Source: Texas Behavioral Risk Factor Surveilla...
# 6529  Data is pulled from the Texas State Health & H...
# 6530                                              BRFSS
# 6531                                                NaN
# ...                                                 ...
# 7146                                               CHIS
# 7147                                     Colorado BRFSS
# 7148       California Health Interview Survey (AskCHIS)
# 7149                                  PA Eddie-->BRFSS
# 7150                                                NaN
# 7151                                              BRFSS
# 7152                                                NaN
# 7153                                     Colorado BRFSS
# 7154       California Health Interview Survey (AskCHIS)
# 7155                                              BRFSS
# 7156                                     Colorado BRFSS
# 7157                                  PA Eddie-->BRFSS
# 7158       California Health Interview Survey (AskCHIS)
# 7159                                     Colorado BRFSS
# 7160                                                NaN
# 7161       California Health Interview Survey (AskCHIS)
# 7162                                     Colorado BRFSS
# 7163                                                NaN
# 7164                                     Colorado BRFSS
# 7165                                  PA Eddie-->BRFSS
# 7166                                              BRFSS
# 7167       California Health Interview Survey (AskCHIS)
# 7168                                     Colorado BRFSS
# 7169                                              BRFSS
# 7170                                  PA Eddie-->BRFSS
# 7171       California Health Interview Survey (AskCHIS)
# 7172                                     Colorado BRFSS
# 7173                                  PA Eddie-->BRFSS
# 7174                                              BRFSS
# 7175       California Health Interview Survey (AskCHIS)
#
#                                                 Methods  \
# 6502                                                NaN
# 6503                                                NaN
# 6504                                                NaN
# 6505                                                NaN
# 6506  The three most recent years of available data ...
# 6507                                                NaN
# 6508  crude rate of BMI>=30 in Houston-Baytown-Sugar...
# 6509                                                NaN
# 6510                                                NaN
# 6511                                                NaN
# 6512                                                NaN
# 6513                                                NaN
# 6514                                                NaN
# 6515                                                NaN
# 6516                                                NaN
# 6517  The three most recent years of available data ...
# 6518                                                NaN
# 6519                                                NaN
# 6520                                                NaN
# 6521                                                NaN
# 6522                                                NaN
# 6523  crude rate of BMI>=30 in Houston-Baytown-Sugar...
# 6524                                                NaN
# 6525                                                NaN
# 6526                                                NaN
# 6527                                                NaN
# 6528  crude rate of BMI>=30 in Houston-Baytown-Sugar...
# 6529                                                NaN
# 6530                                                NaN
# 6531                                                NaN
# ...                                                 ...
# 7146                                                NaN
# 7147                                     Colorado BRFSS
# 7148  California Health Interview Survey. Percent of...
# 7149                                                NaN
# 7150                                                NaN
# 7151                                                NaN
# 7152                                                NaN
# 7153                                     Colorado BRFSS
# 7154  California Health Interview Survey. Percent of...
# 7155                                                NaN
# 7156                                     Colorado BRFSS
# 7157                                                NaN
# 7158  California Health Interview Survey. Percent of...
# 7159                                     Colorado BRFSS
# 7160                                                NaN
# 7161  California Health Interview Survey. Percent of...
# 7162                                                NaN
# 7163                                                NaN
# 7164                                     Colorado BRFSS
# 7165                                                NaN
# 7166                                                NaN
# 7167  California Health Interview Survey. Percent of...
# 7168                                     Colorado BRFSS
# 7169                                                NaN
# 7170                                                NaN
# 7171  California Health Interview Survey. Percent of...
# 7172                                     Colorado BRFSS
# 7173                                                NaN
# 7174                                                NaN
# 7175  California Health Interview Survey. Percent of...
#
#                                                   Notes  \
# 6502                                                NaN
# 6503             This survey is not conducted annually.
# 6504                                                NaN
# 6505                                                NaN
# 6506  Due to changes in BRFSS sampling methodology, ...
# 6507                                                NaN
# 6508  Data for the Houston-Baytown-Sugarland MSA, no...
# 6509                                                NaN
# 6510                     2014 data are actually 2014-15
# 6511                            Bexar County level data
# 6512               Tarrant County (not just Fort Worth)
# 6513  Records where the value is blank in the data t...
# 6514  Does not include Pacific Islander; Records whe...
# 6515                            Bexar County level data
# 6516             This survey is not conducted annually.
# 6517  Due to changes in BRFSS sampling methodology, ...
# 6518                                                NaN
# 6519                                                NaN
# 6520                                                NaN
# 6521                     2014 data are actually 2014-15
# 6522                                                NaN
# 6523  Data for the Houston-Baytown-Sugarland MSA, no...
# 6524             This survey is not conducted annually.
# 6525                                                NaN
# 6526                                                NaN
# 6527                     2014 data are actually 2014-15
# 6528  Data for the Houston-Baytown-Sugarland MSA, no...
# 6529                            Bexar County level data
# 6530                                                NaN
# 6531  Records where the value is blank in the data t...
# ...                                                 ...
# 7146  Records where the value is blank in the data t...
# 7147                                                NaN
# 7148                       Data is for Alameda County.
# 7149                                                NaN
# 7150                                                NaN
# 7151                                                NaN
# 7152  Records where the value is blank in the data t...
# 7153  Records where the value is blank in the data t...
# 7154  Data is for Alameda County; Records where the ...
# 7155                                                NaN
# 7156                                                NaN
# 7157                                                NaN
# 7158  Data is for Alameda County; Records where the ...
# 7159                                                NaN
# 7160  Records where the value is blank in the data t...
# 7161  Data is for Alameda County; Records where the ...
# 7162                                  Includes Asian/PI
# 7163  Records where the value is blank in the data t...
# 7164                                                NaN
# 7165                                                NaN
# 7166                                                NaN
# 7167  Data is for Alameda County; Records where the ...
# 7168                                                NaN
# 7169                                                NaN
# 7170                                                NaN
# 7171  Data is for Alameda County; Records where the ...
# 7172                                                NaN
# 7173                                                NaN
# 7174                                                NaN
# 7175  Data is for Alameda County; Records where the ...
#
#       90% Confidence Level - Low  90% Confidence Level - High  \
# 6502                         NaN                          NaN
# 6503                         NaN                          NaN
# 6504                         NaN                          NaN
# 6505                         NaN                          NaN
# 6506                         NaN                          NaN
# 6507                         NaN                          NaN
# 6508                         NaN                          NaN
# 6509                         NaN                          NaN
# 6510                         NaN                          NaN
# 6511                         NaN                          NaN
# 6512                         NaN                          NaN
# 6513                         NaN                          NaN
# 6514                         NaN                          NaN
# 6515                         NaN                          NaN
# 6516                         NaN                          NaN
# 6517                         NaN                          NaN
# 6518                         NaN                          NaN
# 6519                         NaN                          NaN
# 6520                         NaN                          NaN
# 6521                         NaN                          NaN
# 6522                         NaN                          NaN
# 6523                         NaN                          NaN
# 6524                         NaN                          NaN
# 6525                         NaN                          NaN
# 6526                         NaN                          NaN
# 6527                         NaN                          NaN
# 6528                         NaN                          NaN
# 6529                         NaN                          NaN
# 6530                         NaN                          NaN
# 6531                         NaN                          NaN
# ...                          ...                          ...
# 7146                         NaN                          NaN
# 7147                         NaN                          NaN
# 7148                         NaN                          NaN
# 7149                         NaN                          NaN
# 7150                         NaN                          NaN
# 7151                         NaN                          NaN
# 7152                         NaN                          NaN
# 7153                         NaN                          NaN
# 7154                         NaN                          NaN
# 7155                         NaN                          NaN
# 7156                         NaN                          NaN
# 7157                         NaN                          NaN
# 7158                         NaN                          NaN
# 7159                         NaN                          NaN
# 7160                         NaN                          NaN
# 7161                         NaN                          NaN
# 7162                         NaN                          NaN
# 7163                         NaN                          NaN
# 7164                         NaN                          NaN
# 7165                         NaN                          NaN
# 7166                         NaN                          NaN
# 7167                         NaN                          NaN
# 7168                         NaN                          NaN
# 7169                         NaN                          NaN
# 7170                         NaN                          NaN
# 7171                         NaN                          NaN
# 7172                         NaN                          NaN
# 7173                         NaN                          NaN
# 7174                         NaN                          NaN
# 7175                         NaN                          NaN
#
#       95% Confidence Level - Low  95% Confidence Level - High
# 6502                        14.0                         22.0
# 6503                        18.1                         22.5
# 6504                         NaN                          NaN
# 6505                        21.8                         31.6
# 6506                         NaN                          NaN
# 6507                         NaN                          NaN
# 6508                        27.9                         33.5
# 6509                         NaN                          NaN
# 6510                         NaN                          NaN
# 6511                        28.4                         36.5
# 6512                         NaN                          NaN
# 6513                         NaN                          NaN
# 6514                         NaN                          NaN
# 6515                        17.3                         43.1
# 6516                        27.4                         37.3
# 6517                         NaN                          NaN
# 6518                         NaN                          NaN
# 6519                        20.0                         58.0
# 6520                         NaN                          NaN
# 6521                         NaN                          NaN
# 6522                        28.5                         50.3
# 6523                        37.2                         53.0
# 6524                        21.9                         35.0
# 6525                         NaN                          NaN
# 6526                         NaN                          NaN
# 6527                         NaN                          NaN
# 6528                        32.0                         45.7
# 6529                        32.5                         47.1
# 6530                        25.0                         66.0
# 6531                         NaN                          NaN
# ...                          ...                          ...
# 7146                         NaN                          NaN
# 7147                        15.8                         21.1
# 7148                        12.4                         41.5
# 7149                        24.0                         33.0
# 7150                         NaN                          NaN
# 7151                        27.3                         39.0
# 7152                         NaN                          NaN
# 7153                         NaN                          NaN
# 7154                         NaN                          NaN
# 7155                        21.1                         43.4
# 7156                        21.9                         46.5
# 7157                        30.0                         44.0
# 7158                         NaN                          NaN
# 7159                        16.2                         27.3
# 7160                         NaN                          NaN
# 7161                         NaN                          NaN
# 7162                         3.3                         25.1
# 7163                         NaN                          NaN
# 7164                        12.1                         18.2
# 7165                        18.0                         30.0
# 7166                        24.9                         39.5
# 7167                         NaN                          NaN
# 7168                        15.4                         23.1
# 7169                        23.4                         38.5
# 7170                        30.0                         42.0
# 7171                         NaN                          NaN
# 7172                        14.2                         21.3
# 7173                        15.0                         26.0
# 7174                        26.4                         44.0
# 7175                         NaN                          NaN
#
# [674 rows x 15 columns]

# %% [markdown]
# Obesity Hypothesis
#
# I predict that there will be a inverse corellation between median income and obesity rate on a city by city basis
#
# Cities in the south and midwest have a higher than average obesity rate, cities in the northeast and west coast have a lower than average obesity rate
#
# Lower physical activity levels correlate with higher obesity
#
# Higher disability rate correllates with higher obesity rate

# %%
#get income data
incomes = df[df["Indicator"] == "Median Household Income (Dollars)"]
incomes.rename(columns={'Value':'Income'},inplace=True)

# get obesity data    
obesity = df[(df["Indicator"] == "Percent of Adults Who Are Obese") &
            (df["Race/Ethnicity"] == "All") &
            (df["Sex"] == "Both")]
obesity.rename(columns={'Value':'Obesity'},inplace=True)

ob_data = pandas.merge(incomes, obesity, on=["Place", "Year"], how="inner")

# graph the output
import matplotlib.pyplot as plt
import seaborn

seaborn.relplot(x="Income", y="Obesity", data=ob_data)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_validate, ShuffleSplit

X = ob_data[["Income"]]
y = ob_data["Obesity"]

model = LinearRegression()
res = cross_validate(model, X, y, cv=10)
print(res["test_score"].mean())

ob_data.corr().head()
# Out:
# 0.2530990331556403
#                                    Year    Income  \
# Year                           1.000000  0.187199
# Income                         0.187199  1.000000
# 90% Confidence Level - Low_x        NaN       NaN
# 90% Confidence Level - High_x       NaN       NaN
# 95% Confidence Level - Low_x        NaN       NaN
#
#                                90% Confidence Level - Low_x  \
# Year                                                    NaN
# Income                                                  NaN
# 90% Confidence Level - Low_x                            NaN
# 90% Confidence Level - High_x                           NaN
# 95% Confidence Level - Low_x                            NaN
#
#                                90% Confidence Level - High_x  \
# Year                                                     NaN
# Income                                                   NaN
# 90% Confidence Level - Low_x                             NaN
# 90% Confidence Level - High_x                            NaN
# 95% Confidence Level - Low_x                             NaN
#
#                                95% Confidence Level - Low_x  \
# Year                                                    NaN
# Income                                                  NaN
# 90% Confidence Level - Low_x                            NaN
# 90% Confidence Level - High_x                           NaN
# 95% Confidence Level - Low_x                            NaN
#
#                                95% Confidence Level - High_x   Obesity  \
# Year                                                     NaN  0.104833
# Income                                                   NaN -0.697650
# 90% Confidence Level - Low_x                             NaN       NaN
# 90% Confidence Level - High_x                            NaN       NaN
# 95% Confidence Level - Low_x                             NaN       NaN
#
#                                90% Confidence Level - Low_y  \
# Year                                                    NaN
# Income                                                  NaN
# 90% Confidence Level - Low_x                            NaN
# 90% Confidence Level - High_x                           NaN
# 95% Confidence Level - Low_x                            NaN
#
#                                90% Confidence Level - High_y  \
# Year                                                     NaN
# Income                                                   NaN
# 90% Confidence Level - Low_x                             NaN
# 90% Confidence Level - High_x                            NaN
# 95% Confidence Level - Low_x                             NaN
#
#                                95% Confidence Level - Low_y  \
# Year                                              -0.093243
# Income                                            -0.794615
# 90% Confidence Level - Low_x                            NaN
# 90% Confidence Level - High_x                           NaN
# 95% Confidence Level - Low_x                            NaN
#
#                                95% Confidence Level - High_y
# Year                                                0.066988
# Income                                             -0.612335
# 90% Confidence Level - Low_x                             NaN
# 90% Confidence Level - High_x                            NaN
# 95% Confidence Level - Low_x                             NaN

# %% [markdown]
# **Hypothesis:** Obesity rate shares an inverse correlation with median income level
#
# **Testing Method:** Using the data set, get the median income each year in each city. Match with the obesity rate each year in each city in a new dataframe. Graph the dataframe with seaborn and get the correllation value. Then use the pandas `corr()` function to find correlations in the data.
#
# **Conclusion:** There appears to be a 70% inverse correlation between income level and obesity rate
